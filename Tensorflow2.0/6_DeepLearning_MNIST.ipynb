# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.datasets import mnist

(x_train, t_train), (x_test, t_test) = mnist.load_data()

print('\n train shape = ', x_train.shape, ', train label shape= ', t_train.shape)
print(' test shape = ', x_test.shape, ', test label shape = ' , t_test.shape)

print('\ntrain label = ', t_train)  # 학습데이터 정답 출력
print('test label  = ', t_test)     # 테스트 데이터 정답 출력
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
#
#  train shape =  (60000, 28, 28) , train label shape=  (60000,)
#  test shape =  (10000, 28, 28) , test label shape =  (10000,)
#
# train label =  [5 0 4 ... 5 6 8]
# test label  =  [7 2 1 ... 4 5 6]

# %%
import matplotlib.pyplot as plt

# 25개의 이미지 출력
plt.figure(figsize=(6, 6))

for index in range(25):
    plt.subplot(5, 5, index + 1)    # 5행 5열
    plt.imshow(x_train[index], cmap='gray')
    plt.axis('off')
    # plt.title(str(t_train[index]))

plt.show()

# %%
plt.imshow(x_train[9], cmap='gray')
plt.colorbar()
plt.show()

# %%
# 학습 데이터 / 테스트 데이터 정규화 (Normalization)

x_train = (x_train - 0.0) / (255.0 - 0.0)

x_test = (x_test - 0.0) / (255.0 - 0.0)


# 정답 데이터 원핫 인코딩 (One-Hot Encoding)

t_train = tf.keras.utils.to_categorical(t_train, num_classes=10)

t_test = tf.keras.utils.to_categorical(t_test, num_classes=10)
# MNIST 정답 데이터는 0~9 까지 총 10 개의 숫자 가운데 하나이므로, num_classes=10 지정하여 10개의 리스트를 만들어서 원핫 인코딩을 수행함

# %%
model = tf.keras.Sequential()

model.add(tf.keras.layers.Flatten(input_shape=(28, 28)))    # 28x28 크기 2차원 이미지를 784 개의 1차원 벡터로 변환

model.add(tf.keras.layers.Dense(100, activation='relu'))

model.add(tf.keras.layers.Dense(10, activation='softmax'))

# %%
# 정답을 원핫 인코딩 방식으로 나타냈기 때문에 loss='categorical_crossentropy'
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3), loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 100)               78500
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1010
# =================================================================
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(x_train, t_train, epochs=30, validation_split=0.3) # training data로 부터 30% 비율로 validation data 생성후 overfitting 확인
# Out:
# Epoch 1/30
# 1313/1313 [==============================] - 4s 3ms/step - loss: 0.3204 - accuracy: 0.9101 - val_loss: 0.1981 - val_accuracy: 0.9438
# Epoch 2/30
# 1313/1313 [==============================] - 3s 3ms/step - loss: 0.1496 - accuracy: 0.9568 - val_loss: 0.1680 - val_accuracy: 0.9498
# Epoch 3/30
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.1052 - accuracy: 0.9688 - val_loss: 0.1238 - val_accuracy: 0.9637
# Epoch 4/30
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.0796 - accuracy: 0.9760 - val_loss: 0.1099 - val_accuracy: 0.9673
# Epoch 5/30
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.0620 - accuracy: 0.9818 - val_loss: 0.1099 - val_accuracy: 0.9677
# Epoch 6/30
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.0489 - accuracy: 0.9852 - val_loss: 0.1034 - val_accuracy: 0.9694
# Epoch 7/30
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.0388 - accuracy: 0.9886 - val_loss: 0.0999 - val_accuracy: 0.9725
# Epoch 8/30
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.0314 - accuracy: 0.9910 - val_loss: 0.1195 - val_accuracy: 0.9667
# Epoch 9/30
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.0262 - accuracy: 0.9923 - val_loss: 0.1130 - val_accuracy: 0.9709
# Epoch 10/30
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.0218 - accuracy: 0.9940 - val_loss: 0.1071 - val_accuracy: 0.9726
# Epoch 11/30
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.0176 - accuracy: 0.9950 - val_loss: 0.1113 - val_accuracy: 0.9722
# Epoch 12/30
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.0142 - accuracy: 0.9959 - val_loss: 0.1076 - val_accuracy: 0.9732
# Epoch 13/30
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.0116 - accuracy: 0.9970 - val_loss: 0.1195 - val_accuracy: 0.9724
# Epoch 14/30
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.0105 - accuracy: 0.9973 - val_loss: 0.1162 - val_accuracy: 0.9719
# Epoch 15/30
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.0094 - accuracy: 0.9976 - val_loss: 0.1424 - val_accuracy: 0.9667
# Epoch 16/30
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.0073 - accuracy: 0.9983 - val_loss: 0.1171 - val_accuracy: 0.9747
# Epoch 17/30
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.0080 - accuracy: 0.9979 - val_loss: 0.1227 - val_accuracy: 0.9731
# Epoch 18/30
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.0063 - accuracy: 0.9981 - val_loss: 0.1358 - val_accuracy: 0.9718
# Epoch 19/30
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.0055 - accuracy: 0.9984 - val_loss: 0.1386 - val_accuracy: 0.9728
# Epoch 20/30
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.0063 - accuracy: 0.9980 - val_loss: 0.1483 - val_accuracy: 0.9692
# Epoch 21/30
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.0050 - accuracy: 0.9988 - val_loss: 0.1480 - val_accuracy: 0.9712
# Epoch 22/30
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.0062 - accuracy: 0.9981 - val_loss: 0.1553 - val_accuracy: 0.9710
# Epoch 23/30
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.0034 - accuracy: 0.9992 - val_loss: 0.1375 - val_accuracy: 0.9749
# Epoch 24/30
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.1460 - val_accuracy: 0.9736
# Epoch 25/30
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.0076 - accuracy: 0.9976 - val_loss: 0.1685 - val_accuracy: 0.9701
# Epoch 26/30
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.0039 - accuracy: 0.9988 - val_loss: 0.1509 - val_accuracy: 0.9736
# Epoch 27/30
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.0039 - accuracy: 0.9988 - val_loss: 0.1545 - val_accuracy: 0.9729
# Epoch 28/30
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.0040 - accuracy: 0.9988 - val_loss: 0.1548 - val_accuracy: 0.9732
# Epoch 29/30
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 0.1519 - val_accuracy: 0.9748
# Epoch 30/30
# 1313/1313 [==============================] - 3s 2ms/step - loss: 0.0039 - accuracy: 0.9988 - val_loss: 0.1619 - val_accuracy: 0.9744

# %%
model.evaluate(x_test, t_test)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1328 - accuracy: 0.9756
# [0.13276365399360657, 0.975600004196167]

# %%
plt.title('Loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.grid()

plt.plot(hist.history['loss'], label='train loss')
plt.plot(hist.history['val_loss'], label='validation loss')

plt.legend(loc='best')

plt.show()

# %%
plt.title('Accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.grid()

plt.plot(hist.history['accuracy'], label='train accuracy')
plt.plot(hist.history['val_accuracy'], label='validaton accuracy')

plt.legend(loc='best')
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

plt.figure(figsize=(6, 6))
# 테이스 입력 데이터에 대한 prediction 실행
predicted_value = model.predict(x_test)

cm = confusion_matrix(np.argmax(t_test, axis=-1), np.argmax(predicted_value, axis=-1))

sns.heatmap(cm, annot=True, fmt='d')
plt.show()

# %%
print(cm)
print('\n')

for i in range(10):
    print(('label = %d\t(%d/%d)\taccuracy = %.3f') % (i, np.max(cm[i]), np.sum(cm[i]), np.max(cm[i])/np.sum(cm[i])))

# 0에 대해서는 대부분 맞추는 반면에 5에 대해서는 많이 혼란스러워함
# Out:
# [[ 969    0    0    3    1    0    5    1    1    0]
#  [   0 1122    5    0    0    1    2    1    4    0]
#  [   3    2 1013    2    2    0    3    4    2    1]
#  [   0    0    6  985    0    6    0    4    5    4]
#  [   1    0    5    1  954    1    4    3    3   10]
#  [   3    1    0    7    1  865    6    1    6    2]
#  [   5    3    1    1    3    4  940    0    1    0]
#  [   2    4   11    1    0    0    0 1002    4    4]
#  [   5    0    8    6    5    7    2    3  934    4]
#  [   2    4    0    4   10    4    1    7    5  972]]
#
#
# label = 0	(969/980)	accuracy = 0.989
# label = 1	(1122/1135)	accuracy = 0.989
# label = 2	(1013/1032)	accuracy = 0.982
# label = 3	(985/1010)	accuracy = 0.975
# label = 4	(954/982)	accuracy = 0.971
# label = 5	(865/892)	accuracy = 0.970
# label = 6	(940/958)	accuracy = 0.981
# label = 7	(1002/1028)	accuracy = 0.975
# label = 8	(934/974)	accuracy = 0.959
# label = 9	(972/1009)	accuracy = 0.963
