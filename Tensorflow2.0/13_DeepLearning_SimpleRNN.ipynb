# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.layers import SimpleRNN, Dense
from tensorflow.keras import Sequential

# %%
# 시계열 데이터 y = 0.5sin(x)-cos(x/2) 정의
# 1000개의 시계열 데이터
x = np.arange(0, 100, 0.1)
y = 0.5*np.sin(2*x) - np.cos(x/2.0)

# RNN 입력에 필수적인(batch size, time steps, imput_dim) 3차원 텐서 형태의 입력 데이터로 쉽게 만들기 위해서
# reshape(-1, 1) 사용하여 (1000, 1) 행렬로 바꾸어줌
seq_data = y.reshape(-1, 1)

print(seq_data.shape)
print(seq_data[:10])
# Out:
# (1000, 1)
# [[-1.        ]
#  [-0.89941559]
#  [-0.80029499]
#  [-0.70644984]
#  [-0.62138853]
#  [-0.54817693]
#  [-0.48931695]
#  [-0.44664785]
#  [-0.42127419]
#  [-0.41352329]]

# %%
plt.grid()
plt.title('0.5*sin(2x)-cos(x/2)')
plt.xlabel('time')
plt.ylabel('amplitude')
plt.plot(seq_data)

plt.show()

# %%
def seq2dataset(seq, window, horizon):

    X = [] # 입력 데이터를 저장하는 list
    Y = [] # 정답 데이터를 저장하는 list

    for i in range(len(seq)-(window+horizon)+1):

        x = seq[i:(i+window)] # 슬라이싱을 이용하여 [[...], [...], ...] 형상으로 x 데이터를 생성함
        y = (seq[i+window+horizon-1])

        X.append(x)
        Y.append(y)
    return np.array(X), np.array(Y) # x.shape = [[...], [...], ...] 은 2차원 행렬인데,
                # np.array(X)를 통해서 (batch size, time steps, imput dims) 형상을 가지능 3차원 텐서로 변환되어 리턴됨

# %%
# 입력 데이터 X, 정답 데이터 Y 생성
w = 20 # window size
h = 1 # horizon factor

X, Y = seq2dataset(seq_data, w, h)
# 시계열 데이터 seq_data로 부터 window size w, horizen factor h에 맞게 RNN 입력데이터 X, 정답 데이터 Y 생성함.
# 이때 리턴되는 입력 데이터 X.shape = (batch size, time steps, imput dims)
print(X.shape, Y.shape)
# Out:
# (980, 20, 1) (980, 1)

# %%
# 트레이닝 테이터 / 테스트 데이터 분리
split_ratio = 0.8

split = int(split_ratio*len(X))

x_train = X[0:split]
y_train = Y[0:split]

x_test = X[split:]
y_test = Y[split:]

print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (784, 20, 1) (784, 1)
# (196, 20, 1) (196, 1)

# %%
# SimpleRNN 모델 구축
model = Sequential()

model.add(SimpleRNN(units=128, activation='tanh', input_shape=x_train[0].shape))

model.add(Dense(1))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn (SimpleRNN)       (None, 128)               16640
# _________________________________________________________________
# dense (Dense)                (None, 1)                 129
# =================================================================
# Total params: 16,769
# Trainable params: 16,769
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mse', optimizer='adam', metrics=['mae'])

hist = model.fit(x_train, y_train, epochs=100, validation_data=(x_test, y_test))
# Out:
# Epoch 1/100
# 25/25 [==============================] - 3s 48ms/step - loss: 0.0692 - mae: 0.1660 - val_loss: 0.0084 - val_mae: 0.0782
# Epoch 2/100
# 25/25 [==============================] - 1s 38ms/step - loss: 0.0034 - mae: 0.0455 - val_loss: 0.0017 - val_mae: 0.0344
# Epoch 3/100
# 25/25 [==============================] - 1s 40ms/step - loss: 0.0011 - mae: 0.0263 - val_loss: 7.8548e-04 - val_mae: 0.0232
# Epoch 4/100
# 25/25 [==============================] - 1s 39ms/step - loss: 5.7727e-04 - mae: 0.0194 - val_loss: 5.5542e-04 - val_mae: 0.0201
# Epoch 5/100
# 25/25 [==============================] - 1s 39ms/step - loss: 4.3321e-04 - mae: 0.0167 - val_loss: 3.4092e-04 - val_mae: 0.0149
# Epoch 6/100
# 25/25 [==============================] - 1s 39ms/step - loss: 2.6312e-04 - mae: 0.0131 - val_loss: 1.9958e-04 - val_mae: 0.0116
# Epoch 7/100
# 25/25 [==============================] - 1s 38ms/step - loss: 1.9989e-04 - mae: 0.0114 - val_loss: 3.8562e-04 - val_mae: 0.0170
# Epoch 8/100
# 25/25 [==============================] - 1s 40ms/step - loss: 6.5358e-04 - mae: 0.0203 - val_loss: 2.2616e-04 - val_mae: 0.0126
# Epoch 9/100
# 25/25 [==============================] - 1s 42ms/step - loss: 2.2151e-04 - mae: 0.0120 - val_loss: 1.4373e-04 - val_mae: 0.0097
# Epoch 10/100
# 25/25 [==============================] - 1s 43ms/step - loss: 1.4637e-04 - mae: 0.0098 - val_loss: 1.1674e-04 - val_mae: 0.0082
# Epoch 11/100
# 25/25 [==============================] - 1s 39ms/step - loss: 1.8456e-04 - mae: 0.0108 - val_loss: 1.2586e-04 - val_mae: 0.0092
# Epoch 12/100
# 25/25 [==============================] - 1s 39ms/step - loss: 1.4089e-04 - mae: 0.0097 - val_loss: 1.1746e-04 - val_mae: 0.0090
# Epoch 13/100
# 25/25 [==============================] - 1s 38ms/step - loss: 1.3134e-04 - mae: 0.0091 - val_loss: 1.4891e-04 - val_mae: 0.0106
# Epoch 14/100
# 25/25 [==============================] - 1s 38ms/step - loss: 1.6409e-04 - mae: 0.0102 - val_loss: 1.2588e-04 - val_mae: 0.0097
# Epoch 15/100
# 25/25 [==============================] - 1s 38ms/step - loss: 9.9930e-05 - mae: 0.0080 - val_loss: 6.9969e-05 - val_mae: 0.0069
# Epoch 16/100
# 25/25 [==============================] - 1s 38ms/step - loss: 8.7515e-05 - mae: 0.0074 - val_loss: 9.1820e-05 - val_mae: 0.0083
# Epoch 17/100
# 25/25 [==============================] - 1s 38ms/step - loss: 6.3641e-05 - mae: 0.0062 - val_loss: 5.3364e-05 - val_mae: 0.0057
# Epoch 18/100
# 25/25 [==============================] - 1s 38ms/step - loss: 3.9928e-05 - mae: 0.0051 - val_loss: 1.8685e-05 - val_mae: 0.0034
# Epoch 19/100
# 25/25 [==============================] - 1s 38ms/step - loss: 2.7180e-05 - mae: 0.0040 - val_loss: 1.5630e-05 - val_mae: 0.0030
# Epoch 20/100
# 25/25 [==============================] - 1s 38ms/step - loss: 1.8544e-05 - mae: 0.0033 - val_loss: 1.3832e-05 - val_mae: 0.0029
# Epoch 21/100
# 25/25 [==============================] - 1s 39ms/step - loss: 2.4607e-05 - mae: 0.0037 - val_loss: 2.0400e-05 - val_mae: 0.0035
# Epoch 22/100
# 25/25 [==============================] - 1s 38ms/step - loss: 4.8107e-05 - mae: 0.0055 - val_loss: 2.5287e-05 - val_mae: 0.0042
# Epoch 23/100
# 25/25 [==============================] - 1s 38ms/step - loss: 4.1023e-05 - mae: 0.0050 - val_loss: 3.1078e-05 - val_mae: 0.0047
# Epoch 24/100
# 25/25 [==============================] - 1s 38ms/step - loss: 3.1180e-05 - mae: 0.0045 - val_loss: 1.3321e-05 - val_mae: 0.0030
# Epoch 25/100
# 25/25 [==============================] - 1s 39ms/step - loss: 1.5446e-04 - mae: 0.0097 - val_loss: 5.4251e-04 - val_mae: 0.0200
# Epoch 26/100
# 25/25 [==============================] - 1s 38ms/step - loss: 3.6492e-04 - mae: 0.0153 - val_loss: 9.2980e-05 - val_mae: 0.0074
# Epoch 27/100
# 25/25 [==============================] - 1s 39ms/step - loss: 1.2632e-04 - mae: 0.0090 - val_loss: 3.7432e-05 - val_mae: 0.0048
# Epoch 28/100
# 25/25 [==============================] - 1s 39ms/step - loss: 2.6156e-05 - mae: 0.0041 - val_loss: 3.4590e-05 - val_mae: 0.0046
# Epoch 29/100
# 25/25 [==============================] - 1s 38ms/step - loss: 3.3334e-05 - mae: 0.0046 - val_loss: 1.4857e-05 - val_mae: 0.0031
# Epoch 30/100
# 25/25 [==============================] - 1s 38ms/step - loss: 2.3327e-05 - mae: 0.0039 - val_loss: 2.7041e-05 - val_mae: 0.0043
# Epoch 31/100
# 25/25 [==============================] - 1s 39ms/step - loss: 6.0660e-05 - mae: 0.0064 - val_loss: 1.0493e-04 - val_mae: 0.0087
# Epoch 32/100
# 25/25 [==============================] - 1s 37ms/step - loss: 8.7261e-05 - mae: 0.0075 - val_loss: 1.5901e-05 - val_mae: 0.0034
# Epoch 33/100
# 25/25 [==============================] - 1s 40ms/step - loss: 4.2239e-05 - mae: 0.0052 - val_loss: 1.7377e-05 - val_mae: 0.0034
# Epoch 34/100
# 25/25 [==============================] - 1s 39ms/step - loss: 1.6106e-05 - mae: 0.0031 - val_loss: 1.8608e-05 - val_mae: 0.0035
# Epoch 35/100
# 25/25 [==============================] - 1s 43ms/step - loss: 1.5346e-05 - mae: 0.0031 - val_loss: 2.2437e-05 - val_mae: 0.0039
# Epoch 36/100
# 25/25 [==============================] - 1s 42ms/step - loss: 9.6021e-06 - mae: 0.0024 - val_loss: 5.3314e-06 - val_mae: 0.0018
# Epoch 37/100
# 25/25 [==============================] - 1s 40ms/step - loss: 2.7119e-05 - mae: 0.0041 - val_loss: 2.9782e-05 - val_mae: 0.0047
# Epoch 38/100
# 25/25 [==============================] - 1s 39ms/step - loss: 1.4127e-05 - mae: 0.0030 - val_loss: 1.6069e-05 - val_mae: 0.0033
# Epoch 39/100
# 25/25 [==============================] - 1s 38ms/step - loss: 4.9865e-05 - mae: 0.0054 - val_loss: 4.1752e-05 - val_mae: 0.0054
# Epoch 40/100
# 25/25 [==============================] - 1s 38ms/step - loss: 3.5341e-05 - mae: 0.0049 - val_loss: 4.1936e-05 - val_mae: 0.0052
# Epoch 41/100
# 25/25 [==============================] - 1s 39ms/step - loss: 2.3204e-05 - mae: 0.0038 - val_loss: 1.0366e-05 - val_mae: 0.0026
# Epoch 42/100
# 25/25 [==============================] - 1s 38ms/step - loss: 1.1418e-05 - mae: 0.0027 - val_loss: 1.8938e-05 - val_mae: 0.0038
# Epoch 43/100
# 25/25 [==============================] - 1s 38ms/step - loss: 3.6684e-05 - mae: 0.0049 - val_loss: 1.6724e-04 - val_mae: 0.0112
# Epoch 44/100
# 25/25 [==============================] - 1s 39ms/step - loss: 1.0932e-04 - mae: 0.0083 - val_loss: 1.8309e-05 - val_mae: 0.0035
# Epoch 45/100
# 25/25 [==============================] - 1s 39ms/step - loss: 6.2671e-05 - mae: 0.0063 - val_loss: 2.3685e-05 - val_mae: 0.0042
# Epoch 46/100
# 25/25 [==============================] - 1s 39ms/step - loss: 9.7501e-05 - mae: 0.0081 - val_loss: 4.1012e-05 - val_mae: 0.0053
# Epoch 47/100
# 25/25 [==============================] - 1s 39ms/step - loss: 3.4002e-05 - mae: 0.0046 - val_loss: 2.1731e-05 - val_mae: 0.0038
# Epoch 48/100
# 25/25 [==============================] - 1s 38ms/step - loss: 2.1895e-05 - mae: 0.0037 - val_loss: 6.0568e-06 - val_mae: 0.0020
# Epoch 49/100
# 25/25 [==============================] - 1s 38ms/step - loss: 9.6252e-06 - mae: 0.0024 - val_loss: 7.9514e-06 - val_mae: 0.0023
# Epoch 50/100
# 25/25 [==============================] - 1s 38ms/step - loss: 1.4752e-05 - mae: 0.0030 - val_loss: 1.6603e-05 - val_mae: 0.0034
# Epoch 51/100
# 25/25 [==============================] - 1s 39ms/step - loss: 1.2618e-05 - mae: 0.0029 - val_loss: 7.8887e-06 - val_mae: 0.0022
# Epoch 52/100
# 25/25 [==============================] - 1s 38ms/step - loss: 1.5931e-05 - mae: 0.0032 - val_loss: 6.6225e-06 - val_mae: 0.0021
# Epoch 53/100
# 25/25 [==============================] - 1s 38ms/step - loss: 3.8074e-05 - mae: 0.0051 - val_loss: 1.5807e-04 - val_mae: 0.0105
# Epoch 54/100
# 25/25 [==============================] - 1s 44ms/step - loss: 5.9116e-05 - mae: 0.0062 - val_loss: 1.3198e-04 - val_mae: 0.0095
# Epoch 55/100
# 25/25 [==============================] - 1s 37ms/step - loss: 1.5545e-04 - mae: 0.0101 - val_loss: 5.6703e-05 - val_mae: 0.0063
# Epoch 56/100
# 25/25 [==============================] - 1s 38ms/step - loss: 1.0638e-04 - mae: 0.0080 - val_loss: 5.6351e-05 - val_mae: 0.0062
# Epoch 57/100
# 25/25 [==============================] - 1s 39ms/step - loss: 7.7036e-05 - mae: 0.0069 - val_loss: 2.1473e-04 - val_mae: 0.0122
# Epoch 58/100
# 25/25 [==============================] - 1s 37ms/step - loss: 1.1507e-04 - mae: 0.0088 - val_loss: 6.6258e-05 - val_mae: 0.0068
# Epoch 59/100
# 25/25 [==============================] - 1s 38ms/step - loss: 7.8854e-05 - mae: 0.0071 - val_loss: 3.8888e-05 - val_mae: 0.0052
# Epoch 60/100
# 25/25 [==============================] - 1s 38ms/step - loss: 6.6561e-05 - mae: 0.0067 - val_loss: 4.8823e-05 - val_mae: 0.0058
# Epoch 61/100
# 25/25 [==============================] - 1s 40ms/step - loss: 9.5110e-05 - mae: 0.0080 - val_loss: 3.0256e-04 - val_mae: 0.0153
# Epoch 62/100
# 25/25 [==============================] - 1s 39ms/step - loss: 1.3897e-04 - mae: 0.0098 - val_loss: 8.8867e-05 - val_mae: 0.0083
# Epoch 63/100
# 25/25 [==============================] - 1s 38ms/step - loss: 1.2231e-04 - mae: 0.0091 - val_loss: 8.9849e-05 - val_mae: 0.0079
# Epoch 64/100
# 25/25 [==============================] - 1s 38ms/step - loss: 2.9861e-05 - mae: 0.0042 - val_loss: 1.2952e-05 - val_mae: 0.0031
# Epoch 65/100
# 25/25 [==============================] - 1s 41ms/step - loss: 1.5116e-05 - mae: 0.0031 - val_loss: 8.5603e-06 - val_mae: 0.0023
# Epoch 66/100
# 25/25 [==============================] - 1s 39ms/step - loss: 1.2372e-05 - mae: 0.0027 - val_loss: 5.0613e-06 - val_mae: 0.0018
# Epoch 67/100
# 25/25 [==============================] - 1s 40ms/step - loss: 1.0121e-05 - mae: 0.0025 - val_loss: 3.0582e-05 - val_mae: 0.0047
# Epoch 68/100
# 25/25 [==============================] - 1s 43ms/step - loss: 1.2866e-05 - mae: 0.0029 - val_loss: 4.4449e-06 - val_mae: 0.0017
# Epoch 69/100
# 25/25 [==============================] - 1s 39ms/step - loss: 7.2478e-06 - mae: 0.0021 - val_loss: 7.7265e-06 - val_mae: 0.0024
# Epoch 70/100
# 25/25 [==============================] - 1s 37ms/step - loss: 7.3651e-06 - mae: 0.0022 - val_loss: 4.1475e-06 - val_mae: 0.0016
# Epoch 71/100
# 25/25 [==============================] - 1s 37ms/step - loss: 9.3923e-06 - mae: 0.0024 - val_loss: 1.2200e-05 - val_mae: 0.0029
# Epoch 72/100
# 25/25 [==============================] - 1s 38ms/step - loss: 9.7138e-06 - mae: 0.0026 - val_loss: 2.1137e-05 - val_mae: 0.0038
# Epoch 73/100
# 25/25 [==============================] - 1s 38ms/step - loss: 5.3521e-05 - mae: 0.0059 - val_loss: 1.6047e-05 - val_mae: 0.0034
# Epoch 74/100
# 25/25 [==============================] - 1s 37ms/step - loss: 3.7917e-05 - mae: 0.0050 - val_loss: 2.7512e-05 - val_mae: 0.0041
# Epoch 75/100
# 25/25 [==============================] - 1s 38ms/step - loss: 2.2309e-05 - mae: 0.0038 - val_loss: 1.8014e-05 - val_mae: 0.0034
# Epoch 76/100
# 25/25 [==============================] - 1s 39ms/step - loss: 8.4455e-05 - mae: 0.0074 - val_loss: 1.9080e-04 - val_mae: 0.0119
# Epoch 77/100
# 25/25 [==============================] - 1s 37ms/step - loss: 5.0244e-05 - mae: 0.0056 - val_loss: 4.4025e-05 - val_mae: 0.0052
# Epoch 78/100
# 25/25 [==============================] - 1s 36ms/step - loss: 5.1274e-05 - mae: 0.0059 - val_loss: 1.3937e-05 - val_mae: 0.0030
# Epoch 79/100
# 25/25 [==============================] - 1s 37ms/step - loss: 5.2704e-05 - mae: 0.0059 - val_loss: 7.1813e-05 - val_mae: 0.0074
# Epoch 80/100
# 25/25 [==============================] - 1s 38ms/step - loss: 4.5971e-05 - mae: 0.0053 - val_loss: 9.0206e-05 - val_mae: 0.0082
# Epoch 81/100
# 25/25 [==============================] - 1s 37ms/step - loss: 5.8431e-05 - mae: 0.0061 - val_loss: 2.7524e-05 - val_mae: 0.0044
# Epoch 82/100
# 25/25 [==============================] - 1s 37ms/step - loss: 4.1881e-05 - mae: 0.0050 - val_loss: 1.6944e-05 - val_mae: 0.0033
# Epoch 83/100
# 25/25 [==============================] - 1s 37ms/step - loss: 7.5331e-06 - mae: 0.0021 - val_loss: 7.0674e-06 - val_mae: 0.0021
# Epoch 84/100
# 25/25 [==============================] - 1s 38ms/step - loss: 5.8200e-06 - mae: 0.0019 - val_loss: 5.4336e-06 - val_mae: 0.0018
# Epoch 85/100
# 25/25 [==============================] - 1s 38ms/step - loss: 1.0827e-05 - mae: 0.0026 - val_loss: 5.4417e-06 - val_mae: 0.0019
# Epoch 86/100
# 25/25 [==============================] - 1s 38ms/step - loss: 6.5187e-06 - mae: 0.0021 - val_loss: 4.7837e-06 - val_mae: 0.0017
# Epoch 87/100
# 25/25 [==============================] - 1s 37ms/step - loss: 4.6471e-06 - mae: 0.0017 - val_loss: 3.8656e-06 - val_mae: 0.0016
# Epoch 88/100
# 25/25 [==============================] - 1s 37ms/step - loss: 7.0113e-06 - mae: 0.0021 - val_loss: 4.6568e-06 - val_mae: 0.0018
# Epoch 89/100
# 25/25 [==============================] - 1s 37ms/step - loss: 1.4610e-05 - mae: 0.0029 - val_loss: 2.1004e-04 - val_mae: 0.0133
# Epoch 90/100
# 25/25 [==============================] - 1s 38ms/step - loss: 6.7888e-05 - mae: 0.0066 - val_loss: 1.5893e-05 - val_mae: 0.0030
# Epoch 91/100
# 25/25 [==============================] - 1s 37ms/step - loss: 2.7031e-05 - mae: 0.0042 - val_loss: 2.3284e-05 - val_mae: 0.0039
# Epoch 92/100
# 25/25 [==============================] - 1s 37ms/step - loss: 1.8165e-05 - mae: 0.0034 - val_loss: 5.0346e-06 - val_mae: 0.0018
# Epoch 93/100
# 25/25 [==============================] - 1s 37ms/step - loss: 6.3290e-06 - mae: 0.0020 - val_loss: 4.0255e-05 - val_mae: 0.0056
# Epoch 94/100
# 25/25 [==============================] - 1s 39ms/step - loss: 1.6795e-05 - mae: 0.0033 - val_loss: 3.1449e-05 - val_mae: 0.0047
# Epoch 95/100
# 25/25 [==============================] - 1s 37ms/step - loss: 3.7404e-05 - mae: 0.0050 - val_loss: 7.1834e-05 - val_mae: 0.0072
# Epoch 96/100
# 25/25 [==============================] - 1s 37ms/step - loss: 3.5736e-05 - mae: 0.0047 - val_loss: 1.7169e-05 - val_mae: 0.0033
# Epoch 97/100
# 25/25 [==============================] - 1s 37ms/step - loss: 2.5851e-05 - mae: 0.0041 - val_loss: 2.9954e-05 - val_mae: 0.0044
# Epoch 98/100
# 25/25 [==============================] - 1s 38ms/step - loss: 8.3961e-05 - mae: 0.0074 - val_loss: 8.1991e-05 - val_mae: 0.0078
# Epoch 99/100
# 25/25 [==============================] - 1s 38ms/step - loss: 1.1323e-04 - mae: 0.0084 - val_loss: 5.3944e-05 - val_mae: 0.0056
# Epoch 100/100
# 25/25 [==============================] - 1s 37ms/step - loss: 2.6287e-05 - mae: 0.0040 - val_loss: 3.0518e-05 - val_mae: 0.0045

# %%
# 정확도 및 손실
pred = model.predict(x_test)
print(pred.shape)
# Out:
# (196, 1)

# %%
rand_idx = np.random.randint(0, len(y_test), size=5)

print('random idx = ', rand_idx, '\n')
print('pred = ', pred.flatten()[rand_idx])
print('label = ', y_test.flatten()[rand_idx])

rand_idx = np.random.randint(0, len(y_test), size=5)

print('\n\nrandom idx = ', rand_idx, '\n')
print('pred = ', pred.flatten()[rand_idx])
print('label = ', y_test.flatten()[rand_idx])
# Out:
# random idx =  [104  54  65  41  96]
#
# pred =  [-0.44091654 -0.00927098 -1.2866422  -0.14993156 -0.922333  ]
# label =  [-0.43990196 -0.00556474 -1.28569752 -0.14020025 -0.92589831]
#
#
# random idx =  [141 100  24  38  45]
#
# pred =  [ 1.2266032  -0.8401743   1.2373428  -0.17352596  0.02850309]
# label =  [ 1.23371762 -0.83954079  1.24065961 -0.16737082  0.03820471]

# %%
plt.plot(pred, label='predicton')
plt.plot(y_test, label='label')
plt.grid()
plt.legend(loc='best')

plt.show()
